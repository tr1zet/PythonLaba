# %% [markdown]
# Задание 1 задача «Делаем срезы» Условие
# Дана строка:
# 1) Сначала выведите третий символ этой строки.
# 2) Во второй строке выведите предпоследний символ этой строки.
# 3) В третьей строке выведите первые пять символов этой строки.
# 4) В четвертой строке выведите всю строку, кроме последних двух символов.
# 5) В пятой строке выведите все символы с четными индексами (считая, что индексация начинается с 0. поэтому символы выводятся начиная с первого).
# 6) В шестой строке выведите все символы с нечетными индексами, то есть начиная со второго символа строки.
# 7) В седьмой строке выведите все символы в обратном порядке.
# 8) В восьмой строке выведите все символы строки через один в обратном порядке, начиная с последнего.
# 9) В девятой строке выведите длину данной строки.

# %%
s = input()
print("Слово которое было  написано", s)

# 1. Третий символ
print(s[2])
# 2. Предпоследний символ
print(s[-2])
# 3. Первые пять символов
print(s[:5])
# 4. Вся строка кроме последних двух символов
print(s[:-2])
# 5. Четные индексы (начиная с 0)
print(s[::2])
# 6. Нечетные индексы (начиная с 1)
print(s[1::2])
# 7. В обратном порядке
print(s[::-1])
# 8. Через один в обратном порядке, начиная с последнего
print(s[::-2])
# 9. Длина строки
print(len(s))
# Out:
# Слово которое было  написано Всем привет!
# е
# т
# Всем
# Всем приве
# Ве рвт
# смпие!
# !тевирп месВ
# !еипмс
# 12

# %% [markdown]
# Задание 2 адача «Две половинки»
# Условие
# Дана строка. Разрежьте ее на две равные части (если длина строки - четная, а если длина строки нечетная, то длина первой части должна быть на один символ больше). Переставьте эти две части местами, результат запишите в новую строку и выведите на экран.
# При решении этой задачи не стоит пользоваться инструкцией if.

# %%
s = input()
mid = (len(s) + 1) // 2
result = s[mid:] + s[:mid]
print(result)
# Out:
# ветПри

# %% [markdown]
# Задание 3 задача «Обращение фрагмента»
# Условие
# Дана строка, в которой буква h встречается как минимум два раза. Разверните последовательность символов, заключенную между первым и последним появлением буквы h , в противоположном порядке.

# %%
s = input()
print("Введенная последовательность:", s )
first_h = s.find('h')
last_h = s.rfind('h')
result = s[:first_h+1] + s[last_h-1:first_h:-1] + s[last_h:]
print("Изменная последовательность:", result)
# Out:
# Введенная последовательность: абвгдеёжзиhклмнопрhстуфхцчшщъыьэюя
# Изменная последовательность: абвгдеёжзиhрпонмлкhстуфхцчшщъыьэюя

# %% [markdown]
# Задание 4 задача «Первое и последнее вхождения»
# Условие
# Дана строка. Если в этой строке буква f встречается только один раз, выведите её индекс. Если она встречается два и более раз, выведите индекс её первого и последнего появления. Если буква f в данной строке не встречается, ничего не выводите.
# При решении этой задачи не стоит использовать циклы.

# %%
s = input("Введите слово:")
print("Введенное слово пользователем:", s)
first_f = s.find('f')
last_f = s.rfind('f')

if first_f == -1:  
    pass  
elif first_f == last_f:  # если только один раз
    print(first_f)
else:  # если два и более раз
    print(first_f, last_f)
# Out:
# Введенное слово пользователем: pfress  f
# 1 8

# %% [markdown]
# Задание 5 Пользователь (или несколько пользователей за одним компьютером) вводит слова. Начиная
# со второго введённого слова, программа проверяет, совпадает ли первая буква свежевведённого слова с последней буквой предыдущего. Если да, то программа работает
# дальше (считывает очередное слово). Если нет — выводит последнее на этот момент введённое слово и завершает работу.

# %%
prev = input("Первое слово:")
print("Введенное первое слово:", prev)  
while True:
    curr = input("Следующее Cлово")
    print("Введенные следующие слова:", curr)  
    if curr[0].lower() != prev[-1].lower():
        print(curr)
        break
    prev = curr
# Out:
# Введенное первое слово: кот
# Введенные следующие слова: ток
# Введенные следующие слова: кот
# Введенные следующие слова: ток
# Введенные следующие слова: стоп
# стоп

# %% [markdown]
# Задание 6 Выведите слово так, как будто ему что-то мешает произноситься. Каждую букву нужно
# вывести столько раз, каков ее номер в строке.

# %%
word = input()
print("Введенное слово:", word)
result = ""
for i, letter in enumerate(word):
    result += letter * (i + 1)
print(result)
# Out:
# Введенное слово: медленне
# меедддллллееееенннннннннннннееееееее

# %% [markdown]
# Задание 7 Изобразите извилистый спуск улитки по стене по заданной траектории. Вводится одна строка. Начальный символ этой строки — символ рисования пути улитки. Далее следует последовательность символов “<”, “>” и “V”, которые означают движение улитки, соответственно, влево, вправо и вниз. Гарантируется, что по любой горизонтали движение происходит только в одну сторону (иными словами, между идущими в любом порядке “<” и “>” всегда есть хотя бы один “V”) и что путь не пройдёт левее начального положения. Выводятся несколько строк, состоящих из символов рисования пути и пробелов. Верхний левый угол соответствует начальному положению улитки. Каждый последующий символ входной строки означает, что нужно дорисовать символ рисования пути левее, правее или ниже предыдущего. Пробелы используются для отступов.

# %%
path = input()
print("Введенная пользователем функция", path)
draw_char = path[0] 
moves = path[1:] 
# Начальная позиция
row, col = 0, 0
min_col = 0
max_col = 0
max_row = 0

for move in moves:
    if move == '<':
        col -= 1
    elif move == '>':
        col += 1
    elif move == 'V':
        row += 1
    min_col = min(min_col, col)
    max_col = max(max_col, col)
    max_row = max(max_row, row)

# Сетку нужного размера
width = max_col - min_col + 1
height = max_row + 1
grid = [[' ' for _ in range(width)] for _ in range(height)]

row, col = 0, -min_col  
grid[row][col] = draw_char

for move in moves:
    if move == '<':
        col -= 1
    elif move == '>':
        col += 1
    elif move == 'V':
        row += 1
    grid[row][col] = draw_char

for r in range(height):
    print(''.join(grid[r]))
# Out:
# Введенная пользователем функция @VVV>>>>>>>>>>>>V<<VVV<<<VV>>>
# @
# @
# @
# @@@@@@@@@@@@@
#           @@@
#           @
#           @
#        @@@@
#        @
#        @@@@

# %% [markdown]
# Задание 8 Давайте попробуем на самом деле растянуть слова, как будто они резиновые. Возьмём за середину и будем тянуть. Если в слове нечётное количество букв, на верхушке окажется
# одна буква. А вот если чётное, то тянуть будем за две средние буквы, они и окажутся наверху. Напишите программу, которая покажет, как будет выглядеть растянутое слово.
# При решении задачи можно использовать только циклы и операции над строками и числами

# %%
word = input()
n = len(word)

# Верхняя часть
if n % 2 == 1:  # нечетное
    mid = n // 2
    for i in range(mid + 1):
        spaces = ' ' * (mid - i)
        print(spaces + word[mid - i] + spaces)
    # Нижняя часть
    for i in range(mid - 1, -1, -1):
        spaces = ' ' * (mid - i)
        print(spaces + word[i] + spaces)
else:  # четное
    mid_left = n // 2 - 1
    mid_right = n // 2
    for i in range(mid_right):
        spaces = ' ' * (mid_right - 1 - i)
        if i == 0:
            print(spaces + word[mid_left] + word[mid_right] + spaces)
        else:
            print(spaces + word[mid_left - i] + ' ' * (2*i) + word[mid_right + i] + spaces)
# Out:
#   га
#  о  т
# Р    к

# %% [markdown]
# Задание 9 задача "Больше предыдущего"
# Условие
# Дан список чисел. Выведите все элементы списка которые больше предыдущего элемента

# %%
numbers = list(map(int, input().split()))
print("Вывод пользователя до изменения", numbers)
for i in range(1, len(numbers)):
    if numbers[i] > numbers[i-1]:
        print(numbers[i], end=' ')
# Out:
# Вывод пользователя до изменения [1, 5, 2, 4, 3, 6, 7, 2]
# 5 4 6 7

# %% [markdown]
# Задание 10 задача «Соседи одного знака»
# Условие Дан список чисел. Если в нем есть два соседних элемента одного знака, выведите эти числа. Если соседних элементов одного знака нет - не выводите ничего. Если таких пар соседей несколько - выведите первую пару.

# %%
numbers = list(map(int, input().split()))
print("Вывод пользователя до изменения", numbers)
for i in range(1, len(numbers)):
    if numbers[i] * numbers[i-1] > 0:
        print(numbers[i-1], numbers[i])
        break
# Out:
# Вывод пользователя до изменения [1, -2, 3, 4, -5, -6, 7]
# 3 4

# %% [markdown]
# Задание 11 задача «Переставить соседние»
# Условие Переставьте соседние элементы списка ( A[0] с A[1] , A[2] с A[3] ит. д.). Если элементов нечетное число, то последний элемент остается на своем месте.

# %%
numbers = list(map(int, input().split()))
print("Вывод пользователя до изменения", numbers)
for i in range(0, len(numbers) - 1, 2):
    numbers[i], numbers[i+1] = numbers[i+1], numbers[i]
print(' '.join(map(str, numbers)))
# Out:
# Вывод пользователя до изменения [1, 2, 3, 4, 5, 6]
# 2 1 4 3 6 5

# %% [markdown]
# Задание 12 задача «Уникальные элементы»
# Условие Дан список. Выведите те его элементы, которые встречаются в списке только один раз. Элементы нужно выводить в том порядке, в котором они встречаются в списке.

# %%
numbers = list(map(int, input().split()))
print("Вывод пользователя до изменения", numbers)
unique = []
for num in numbers:
    if numbers.count(num) == 1:
        unique.append(num)
print(' '.join(map(str, unique)))
# Out:
# Вывод пользователя до изменения [1, 2, 3, 2, 4, 5, 3, 6, 7, 5, 8]
# 1 4 6 7 8

# %% [markdown]
# Задание 13 Напишите программу, которая составляет новое предложение по номерам слов из исходной строки. Предложение должно начинаться с большой буквы. Гарантируется, что в исходной строке только одна заглавная буква (в начале предложения). Нумерация слов начинается с единицы.

# %%
text = input().split()
indexes = list(map(int, input().split()))
print("Исходное приложение:", text)
print("номера слов:", indexes)
result = []
for i in indexes:
    result.append(text[i-1])

result[0] = result[0].capitalize()
for i in range(1, len(result)):
    result[i] = result[i].lower()

print(' '.join(result))
# Out:
# Исходное приложение: ['всем', 'привет', 'мир']
# номера слов: [3, 1, 2]
# Мир всем привет

# %% [markdown]
# Задание 14 Задача «Ферзи»
# Условие Известно, что на доске 8×8 можно расставить 8 ферзей так, чтобы они не били друг друга. Вам дана расстановка 8 ферзей на доске, определите, есть ли среди них пара бьющих друг друга.
# Программа получает на вход восемы пар чисел. каждое число от 1 до 8 - координаты 8 ферзей. Если ферзи не бьют друг друга, выведите слово No , иначе выведите YES .

# %%
queens = []
print("Введите координаты 8 ферзей (каждая пара чисел от 1 до 8):")
for i in range(8):
    print(f"Ферзь {i+1}:")
    x, y = map(int, input().split())
    queens.append((x, y))
print("\nКоординаты ферзей:")
for i, (x, y) in enumerate(queens, 1):
    print(f"Ферзь {i}: ({x}, {y})")

def check_queens(queens):
    for i in range(8):
        for j in range(i+1, 8):
            x1, y1 = queens[i]
            x2, y2 = queens[j]
            if x1 == x2 or y1 == y2 or abs(x1 - x2) == abs(y1 - y2):
                return True, i+1, j+1, x1, y1, x2, y2
    return False, None, None, None, None, None, None
is_attacking, q1, q2, x1, y1, x2, y2 = check_queens(queens)

if is_attacking:
    print(f"\nYES — ферзи бьют друг друга")
    print(f"Ферзь {q1} ({x1}, {y1}) и ферзь {q2} ({x2}, {y2})")
else:
    print("\nNO — ферзи не бьют друг друга")
# Out:
# Введите координаты 8 ферзей (каждая пара чисел от 1 до 8):
# Ферзь 1:
# Ферзь 2:
# Ферзь 3:
# Ферзь 4:
# Ферзь 5:
# Ферзь 6:
# Ферзь 7:
# Ферзь 8:
#
# Координаты ферзей:
# Ферзь 1: (1, 5)
# Ферзь 2: (2, 3)
# Ферзь 3: (3, 1)
# Ферзь 4: (4, 7)
# Ферзь 5: (5, 2)
# Ферзь 6: (6, 8)
# Ферзь 7: (7, 6)
# Ферзь 8: (8, 4)
#
# NO — ферзи не бьют друг друга

# %% [markdown]
# Задание 15 Окунёмся в суровый и беспощадный мир очереди на приём к врачу в поликлинике.
# Напишите программу-медсестру, которая поможет врачу определить, кто следующий
# проходит к нему в кабинет.
# Изначально в очереди никого нет. Далее в каком-то порядке происходят события трёх
# типов:
# - фраза «Кто последний? Я - <фамилия>.» означает, что пришёл новый пациент и
# встал в конец очереди;
# - фраза «Я только спросить! Я - <фамилия>.» означает, что пришёл новый пациент и
# встал в начало очереди;
# - фраза «Следующий!» означает, что доктор готов принять первого пациента в
# очереди.
# В последнем случае нужно вывести «Заходит <фамилия>!» или «В очереди никого нет.»
# На психологическую достоверность данная модель очереди, конечно, не претендует: в
# жизни такое нахальство с «я только спросить» прощается далеко не всегда

# %%
queue = []
n = int(input("Количество событий: "))

for _ in range(n):
    event = input().strip()
    
    if "Кто последний?" in event:
        name = event.split(" - ")[1].replace(".", "")
        queue.append(name)
    
    elif "Я только спросить!" in event:
        name = event.split(" - ")[1].replace(".", "")
        queue.insert(0, name)
    
    elif event.startswith("Следующий"):
        if queue:
            print(f"Заходит {queue.pop(0)}!")
        else:
            print("В очереди никого нет.")
# Out:
# Заходит Кузнецов!
# Заходит Иванова!
# Заходит Поливанов!
# В очереди никого нет.
